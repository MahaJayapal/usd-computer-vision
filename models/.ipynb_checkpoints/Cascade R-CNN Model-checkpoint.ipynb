# %%
# Import Libraries
# Install MMDetection
# !pip install -U openmim
# !mim install mmdet
# !git clone https://github.com/open-mmlab/mmdetection.git
# %cd mmdetection
# !pip install -e
import opendatasets as od
import os
from PIL import Image
import matplotlib.pyplot as plt
import shutil
import random
import torch
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from mmcv import Config
from mmdet.apis import train_detector, init_detector, inference_detector, show_result_pyplot, single_gpu_test
from mmdet.datasets import build_dataloader, build_dataset
# Out:
# Requirement already satisfied: openmim in c:\users\sassy\anaconda3\lib\site-packages (0.3.9)
# Requirement already satisfied: Click in c:\users\sassy\anaconda3\lib\site-packages (from openmim) (8.1.7)
# Requirement already satisfied: colorama in c:\users\sassy\anaconda3\lib\site-packages (from openmim) (0.4.6)
# Requirement already satisfied: model-index in c:\users\sassy\anaconda3\lib\site-packages (from openmim) (0.1.11)
# Requirement already satisfied: opendatalab in c:\users\sassy\anaconda3\lib\site-packages (from openmim) (0.0.10)
# Requirement already satisfied: pandas in c:\users\sassy\anaconda3\lib\site-packages (from openmim) (2.2.3)
# Requirement already satisfied: pip>=19.3 in c:\users\sassy\anaconda3\lib\site-packages (from openmim) (23.3.1)
# Requirement already satisfied: requests in c:\users\sassy\anaconda3\lib\site-packages (from openmim) (2.28.2)
# Requirement already satisfied: rich in c:\users\sassy\anaconda3\lib\site-packages (from openmim) (13.4.2)
# Requirement already satisfied: tabulate in c:\users\sassy\anaconda3\lib\site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in c:\users\sassy\anaconda3\lib\site-packages (from model-index->openmim) (6.0.1)
# Requirement already satisfied: markdown in c:\users\sassy\anaconda3\lib\site-packages (from model-index->openmim) (3.4.1)
# Requirement already satisfied: ordered-set in c:\users\sassy\anaconda3\lib\site-packages (from model-index->openmim) (4.1.0)
# Requirement already satisfied: pycryptodome in c:\users\sassy\anaconda3\lib\site-packages (from opendatalab->openmim) (3.21.0)
# Requirement already satisfied: tqdm in c:\users\sassy\anaconda3\lib\site-packages (from opendatalab->openmim) (4.65.2)
# Requirement already satisfied: openxlab in c:\users\sassy\anaconda3\lib\site-packages (from opendatalab->openmim) (0.1.2)
# Requirement already satisfied: pywin32 in c:\users\sassy\anaconda3\lib\site-packages (from opendatalab->openmim) (305.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sassy\anaconda3\lib\site-packages (from requests->openmim) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sassy\anaconda3\lib\site-packages (from requests->openmim) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sassy\anaconda3\lib\site-packages (from requests->openmim) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sassy\anaconda3\lib\site-packages (from requests->openmim) (2024.7.4)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\sassy\anaconda3\lib\site-packages (from pandas->openmim) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sassy\anaconda3\lib\site-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sassy\anaconda3\lib\site-packages (from pandas->openmim) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sassy\anaconda3\lib\site-packages (from pandas->openmim) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sassy\anaconda3\lib\site-packages (from rich->openmim) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sassy\anaconda3\lib\site-packages (from rich->openmim) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sassy\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\sassy\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.16.0)
# Requirement already satisfied: filelock~=3.14.0 in c:\users\sassy\anaconda3\lib\site-packages (from openxlab->opendatalab->openmim) (3.14.0)
# Requirement already satisfied: oss2~=2.17.0 in c:\users\sassy\anaconda3\lib\site-packages (from openxlab->opendatalab->openmim) (2.17.0)
# Requirement already satisfied: packaging~=24.0 in c:\users\sassy\anaconda3\lib\site-packages (from openxlab->opendatalab->openmim) (24.2)
# Requirement already satisfied: setuptools~=60.2.0 in c:\users\sassy\anaconda3\lib\site-packages (from openxlab->opendatalab->openmim) (60.2.0)
# Requirement already satisfied: crcmod>=1.7 in c:\users\sassy\anaconda3\lib\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in c:\users\sassy\anaconda3\lib\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.5)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in c:\users\sassy\anaconda3\lib\site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in c:\users\sassy\anaconda3\lib\site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (0.10.0)
# Requirement already satisfied: cryptography>=3.0.0 in c:\users\sassy\anaconda3\lib\site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (42.0.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\sassy\anaconda3\lib\site-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\sassy\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.21)
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.4.0/index.html
# Collecting mmdet
#   Using cached mmdet-3.3.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: matplotlib in c:\users\sassy\anaconda3\lib\site-packages (from mmdet) (3.8.0)
# Requirement already satisfied: numpy in c:\users\sassy\anaconda3\lib\site-packages (from mmdet) (1.23.5)
# Collecting pycocotools (from mmdet)
#   Using cached pycocotools-2.0.8-cp311-cp311-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: scipy in c:\users\sassy\anaconda3\lib\site-packages (from mmdet) (1.10.1)
# Collecting shapely (from mmdet)
#   Using cached shapely-2.0.6-cp311-cp311-win_amd64.whl.metadata (7.2 kB)
# Requirement already satisfied: six in c:\users\sassy\anaconda3\lib\site-packages (from mmdet) (1.16.0)
# Collecting terminaltables (from mmdet)
#   Using cached terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tqdm in c:\users\sassy\anaconda3\lib\site-packages (from mmdet) (4.65.2)
# Collecting mmcv<2.2.0,>=2.0.0rc4 (from mmdet)
#   Using cached mmcv-2.1.0.tar.gz (471 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\sassy\AppData\Local\Temp\pip-install-912bp2_j\mmcv_a1306c83ccc942988f47319b97a143fe\setup.py", line 477, in <module>
#       ext_modules=get_extensions(),
#                   ^^^^^^^^^^^^^^^^
#     File "C:\Users\sassy\AppData\Local\Temp\pip-install-912bp2_j\mmcv_a1306c83ccc942988f47319b97a143fe\setup.py", line 434, in get_extensions
#       ext_ops = extension(
#                 ^^^^^^^^^^
#     File "C:\Users\sassy\anaconda3\Lib\site-packages\torch\utils\cpp_extension.py", line 1076, in CUDAExtension
#       library_dirs += library_paths(cuda=True)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\sassy\anaconda3\Lib\site-packages\torch\utils\cpp_extension.py", line 1214, in library_paths
#       paths.append(_join_cuda_home(lib_dir))
#                    ^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\sassy\anaconda3\Lib\site-packages\torch\utils\cpp_extension.py", line 2416, in _join_cuda_home
#       raise OSError('CUDA_HOME environment variable is not set. '
#   OSError: CUDA_HOME environment variable is not set. Please set it to your CUDA install root.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# [WinError 2] The system cannot find the file specified: 'mmdetection'
# C:\Users\sassy\OneDrive\Documents\GitHub\usd-computer-vision\models
# 'git' is not recognized as an internal or external command,
# operable program or batch file.
#
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# -e option requires 1 argument
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 26
#      24 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#      25 from tensorflow.keras.callbacks import EarlyStopping
# ---> 26 from mmcv import Config
#      27 from mmdet.apis import train_detector, init_detector, inference_detector, show_result_pyplot, single_gpu_test
#      28 from mmdet.datasets import build_dataloader, build_dataset
#
# ModuleNotFoundError: No module named 'mmcv'

# %%
# Load a base configuration for Cascade R-CNN
cfg = Config.fromfile('configs/cascade_rcnn/cascade_rcnn_r50_fpn_1x_coco.py')

# Set dataset paths
cfg.dataset_type = 'CocoDataset'
cfg.data_root = 'data/recyclable_waste/'

cfg.data.train = dict(
    type='CocoDataset',
    ann_file='data/recyclable_waste/annotations/instances_train.json',
    img_prefix='data/recyclable_waste/images/train/',
    classes=('plastic', 'metal', 'paper', 'glass')  # Define your classes
)

cfg.data.val = dict(
    type='CocoDataset',
    ann_file='data/recyclable_waste/annotations/instances_val.json',
    img_prefix='data/recyclable_waste/images/val/',
    classes=('plastic', 'metal', 'paper', 'glass')
)

cfg.data.test = dict(
    type='CocoDataset',
    ann_file='data/recyclable_waste/annotations/instances_val.json',
    img_prefix='data/recyclable_waste/images/val/',
    classes=('plastic', 'metal', 'paper', 'glass')
)

# Adjust model for the custom dataset (e.g., number of classes)
cfg.model.roi_head.bbox_head[0].num_classes = 4
cfg.model.roi_head.bbox_head[1].num_classes = 4
cfg.model.roi_head.bbox_head[2].num_classes = 4

# Output directory for logs and model checkpoints
cfg.work_dir = './work_dirs/cascade_rcnn_recycling'

# Training settings
cfg.optimizer.lr = 0.02  # Adjust learning rate for small datasets
cfg.lr_config.warmup = None
cfg.log_config.interval = 10  # Log every 10 iterations
cfg.runner.max_epochs = 12  # Number of training epochs
cfg.evaluation.metric = 'bbox'

# Enable GPU training
cfg.gpu_ids = range(1)

# Print updated configuration
print(f'Updated Config:\n{cfg.pretty_text}')

# %%
# Initialize the model with the configuration
model = init_detector(cfg, device='cuda:0')

# Train the model
train_detector(model, cfg)

# %%
# Load the trained model
checkpoint = './work_dirs/cascade_rcnn_recycling/latest.pth'
model = init_detector(cfg, checkpoint, device='cuda:0')

# Run inference on a test image
image_path = 'data/recyclable_waste/images/val/test_image.jpg'
result = inference_detector(model, image_path)

# Visualize results
show_result_pyplot(model, image_path, result, score_thr=0.3)

# %%
from mmdet.datasets import build_dataloader, build_dataset

# Build the test dataset and data loader
test_dataset = build_dataset(cfg.data.test)
data_loader = build_dataloader(test_dataset, samples_per_gpu=1, workers_per_gpu=2, dist=False, shuffle=False)

# Run evaluation
results = single_gpu_test(model, data_loader)
print(results)
